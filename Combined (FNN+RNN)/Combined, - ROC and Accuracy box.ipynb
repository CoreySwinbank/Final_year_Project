# %%
import numpy as np
import pandas as pd 

import h5py
#import tables
import matplotlib.pyplot as plt
#import tensorflow as tf
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.utils.class_weight import compute_class_weight

# %%
x=1
y=3
x+y
# Out:
# 4

# %% [markdown]
# # ROC

# %%
with h5py.File('combined_run1_ROC_data.h5', 'r') as hf:
    combined_roc_run1 =  pd.DataFrame(hf['df'][:])  
with h5py.File('combined_run2_ROC_data.h5', 'r') as hf:
    combined_roc_run2 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run3_ROC_data.h5', 'r') as hf:
    combined_roc_run3 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run4_ROC_data.h5', 'r') as hf:
    combined_roc_run4 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run5_ROC_data.h5', 'r') as hf:
    combined_roc_run5 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run6_ROC_data.h5', 'r') as hf:
    combined_roc_run6 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run7_ROC_data.h5', 'r') as hf:
    combined_roc_run7 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run8_ROC_data.h5', 'r') as hf:
    combined_roc_run8 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run9_ROC_data.h5', 'r') as hf:
    combined_roc_run9 =  pd.DataFrame(hf['df'][:])    
with h5py.File('combined_run10_ROC_data.h5', 'r') as hf:
    combined_roc_run10 =  pd.DataFrame(hf['df'][:])

# %%
cols = ['True_Val', 'Predicted', 'Round Prediction']

combined_roc_run1 = combined_roc_run1.rename(columns=dict(zip(combined_roc_run1.columns, cols)))
combined_roc_run2 = combined_roc_run2.rename(columns=dict(zip(combined_roc_run2.columns, cols)))
combined_roc_run3 = combined_roc_run3.rename(columns=dict(zip(combined_roc_run3.columns, cols)))
combined_roc_run4 = combined_roc_run4.rename(columns=dict(zip(combined_roc_run4.columns, cols)))
combined_roc_run5 = combined_roc_run5.rename(columns=dict(zip(combined_roc_run5.columns, cols)))
combined_roc_run6 = combined_roc_run6.rename(columns=dict(zip(combined_roc_run6.columns, cols)))
combined_roc_run7 = combined_roc_run7.rename(columns=dict(zip(combined_roc_run7.columns, cols)))
combined_roc_run8 = combined_roc_run8.rename(columns=dict(zip(combined_roc_run8.columns, cols)))
combined_roc_run9 = combined_roc_run9.rename(columns=dict(zip(combined_roc_run9.columns, cols)))
combined_roc_run10 = combined_roc_run10.rename(columns=dict(zip(combined_roc_run10.columns, cols)))

# %%
#plot ROC curves

y_true1 = combined_roc_run1['True_Val']
y_score1 = combined_roc_run1['Predicted']

# calculate the false positive rate and true positive rate
fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_score1)
# calculate the area under the ROC curve
roc_auc1 = auc(fpr1, tpr1)
# plot the ROC curve
plt.plot(fpr1, tpr1, color='darkorange', lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc1)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()

print(roc_auc1)
# Out:
# 0.7942492716876843

# %%
#plot ROC curves

y_true1 = combined_roc_run1['True_Val']
y_score1 = combined_roc_run1['Predicted']
y_true2 = combined_roc_run2['True_Val']
y_score2 = combined_roc_run2['Predicted']
y_true3 = combined_roc_run3['True_Val']
y_score3 = combined_roc_run3['Predicted']
y_true4 = combined_roc_run4['True_Val']
y_score4 = combined_roc_run4['Predicted']
y_true5 = combined_roc_run5['True_Val']
y_score5 = combined_roc_run5['Predicted']
y_true6 = combined_roc_run6['True_Val']
y_score6 = combined_roc_run6['Predicted']
y_true7 = combined_roc_run7['True_Val']
y_score7 = combined_roc_run7['Predicted']
y_true8 = combined_roc_run8['True_Val']
y_score8 = combined_roc_run8['Predicted']
y_true9 = combined_roc_run9['True_Val']
y_score9 = combined_roc_run9['Predicted']
y_true10 = combined_roc_run10['True_Val']
y_score10 = combined_roc_run10['Predicted']


# calculate the false positive rate and true positive rate
fpr1, tpr1, thresholds1 = roc_curve(y_true1, y_score1)
fpr2, tpr2, thresholds2 = roc_curve(y_true2, y_score2)
fpr3, tpr3, thresholds3 = roc_curve(y_true3, y_score3)
fpr4, tpr4, thresholds4 = roc_curve(y_true4, y_score4)
fpr5, tpr5, thresholds5 = roc_curve(y_true5, y_score5)
fpr6, tpr6, thresholds6 = roc_curve(y_true6, y_score6)
fpr7, tpr7, thresholds7 = roc_curve(y_true7, y_score7)
fpr8, tpr8, thresholds8 = roc_curve(y_true8, y_score8)
fpr9, tpr9, thresholds9 = roc_curve(y_true9, y_score9)
fpr10, tpr10, thresholds10 = roc_curve(y_true10, y_score10)


# calculate the area under the ROC curve
roc_auc1 = auc(fpr1, tpr1)
roc_auc2 = auc(fpr2, tpr2)
roc_auc3 = auc(fpr3, tpr3)
roc_auc4 = auc(fpr4, tpr4)
roc_auc5 = auc(fpr5, tpr5)
roc_auc6 = auc(fpr6, tpr6)
roc_auc7 = auc(fpr7, tpr7)
roc_auc8 = auc(fpr8, tpr8)
roc_auc9 = auc(fpr9, tpr9)
roc_auc10 = auc(fpr10, tpr10)


# plot the ROC curve
plt.plot(fpr1, tpr1, color='darkorange', lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc1)
plt.plot(fpr2, tpr2, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc2)
plt.plot(fpr3, tpr3, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc3)
plt.plot(fpr4, tpr4, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc4)
plt.plot(fpr5, tpr5, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc5)
plt.plot(fpr6, tpr6, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc6)
plt.plot(fpr7, tpr7, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc7)
plt.plot(fpr8, tpr8, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc8)
plt.plot(fpr9, tpr9, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc9)
plt.plot(fpr10, tpr10, lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc10)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()


roc_auc = np.array((roc_auc1,roc_auc2,roc_auc3,roc_auc4,roc_auc5,roc_auc6,roc_auc7,roc_auc8,roc_auc9,roc_auc10))
print(roc_auc)  #79%
# Out:
# [0.79424927 0.7949361  0.79434534 0.79407189 0.79307602 0.79289951
#  0.79353722 0.79252337 0.79314847 0.79244102]

# %%
# plot the ROC curve
plt.plot(fpr1, tpr1, color='orange', lw=0.5, label='ROC curve (AUC = %0.2f)' % roc_auc1)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()

# %%
combined_ROC = {'fpr': fpr7, 'tpr': tpr7}
combined_ROC_df = pd.DataFrame(combined_ROC)


# Save the DataFrame to an HDF5 file
#with h5py.File('combined_ROC_df.h5', 'w') as hf:
   # hf.create_dataset('df', data=combined_ROC_df)

# %%
print(f'The mean AUC is {np.mean(roc_auc):.4f}')
print(f'The standard deviation on AUC is {np.std(roc_auc):.4f}')
# Out:
# The mean AUC is 0.7935
# The standard deviation on AUC is 0.0008

# %%
# create a figure and axis object
fig, ax = plt.subplots()

# create a boxplot of the data in roc_auc
ax.boxplot(roc_auc)

# set axis labels and title
ax.set_ylabel('ROC AUC')
ax.set_xlabel('FNN')
ax.set_title('Boxplot of ROC AUC')
# Out:
# Text(0.5, 1.0, 'Boxplot of ROC AUC')

# %%
# # Plot precision recall curve
# from sklearn.metrics import average_precision_score

# y_true = df['True_Val']
# y_score = df['Predicted']

# # calculate the precision-recall curve
# precision, recall, _ = precision_recall_curve(y_true, y_score)

# # plot the precision-recall curve
# plt.step(recall, precision, color='b', alpha=0.2, where='post')
# plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
# plt.xlabel('Recall')
# plt.ylabel('Precision')
# plt.ylim([0.0, 1.05])
# plt.xlim([0.0, 1.0])
# plt.title('Precision-Recall Curve')
# plt.show()

# AUC = average_precision_score(y_true, y_score)   #0.793, pretty similar to roc AUC
# print(AUC)

# %% [markdown]
# # Accuracies

# %%
with h5py.File('combined_run1_training_data.h5', 'r') as hf:
    combined_history_df_run1 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run2_training_data.h5', 'r') as hf:
    combined_history_df_run2 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run3_training_data.h5', 'r') as hf:
    combined_history_df_run3 = pd.DataFrame(hf['df'][:])

with h5py.File('combined_run4_training_data.h5', 'r') as hf:
    combined_history_df_run4 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run5_training_data.h5', 'r') as hf:
    combined_history_df_run5 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run6_training_data.h5', 'r') as hf:
    combined_history_df_run6 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run7_training_data.h5', 'r') as hf:
    combined_history_df_run7 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run8_training_data.h5', 'r') as hf:
    combined_history_df_run8 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run9_training_data.h5', 'r') as hf:
    combined_history_df_run9 = pd.DataFrame(hf['df'][:])
    
with h5py.File('combined_run10_training_data.h5', 'r') as hf:
    combined_history_df_run10 = pd.DataFrame(hf['df'][:])

# %%
columns = ['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy']

combined_history_df_run1 =combined_history_df_run1.rename(columns=dict(zip(combined_history_df_run1, columns)))
combined_history_df_run2 =combined_history_df_run2.rename(columns=dict(zip(combined_history_df_run2, columns)))
combined_history_df_run3 =combined_history_df_run3.rename(columns=dict(zip(combined_history_df_run3, columns)))
combined_history_df_run4 =combined_history_df_run4.rename(columns=dict(zip(combined_history_df_run4, columns)))
combined_history_df_run5 =combined_history_df_run5.rename(columns=dict(zip(combined_history_df_run5, columns)))
combined_history_df_run6 =combined_history_df_run6.rename(columns=dict(zip(combined_history_df_run6, columns)))
combined_history_df_run7 =combined_history_df_run7.rename(columns=dict(zip(combined_history_df_run7, columns)))
combined_history_df_run8 =combined_history_df_run8.rename(columns=dict(zip(combined_history_df_run8, columns)))
combined_history_df_run9 =combined_history_df_run9.rename(columns=dict(zip(combined_history_df_run9, columns)))
combined_history_df_run10 =combined_history_df_run10.rename(columns=dict(zip(combined_history_df_run10, columns)))

acc1 = max(combined_history_df_run1['binary_accuracy'])
acc2 = max(combined_history_df_run2['binary_accuracy'])
acc3 = max(combined_history_df_run3['binary_accuracy'])
acc4 = max(combined_history_df_run4['binary_accuracy'])
acc5 = max(combined_history_df_run5['binary_accuracy'])
acc6 = max(combined_history_df_run6['binary_accuracy'])
acc7 = max(combined_history_df_run7['binary_accuracy'])
acc8 = max(combined_history_df_run8['binary_accuracy'])
acc9 = max(combined_history_df_run9['binary_accuracy'])
acc10 = max(combined_history_df_run10['binary_accuracy'])

acc_array = np.array((acc1,acc2,acc3,acc4,acc5,acc6,acc7,acc8,acc9,acc10))

# create a figure and axis object
fig, ax = plt.subplots()

# create a boxplot of the data in roc_auc
ax.boxplot(acc_array,showfliers=False)

# set axis labels and title
ax.set_xlabel('FNN')
ax.set_ylabel('Accuracy')
ax.set_title('Boxplot of Accuracies')
#ax.set_ylim(0.7685,0.7745)

acc_array
# Out:
# array([0.73318005, 0.73208195, 0.73140949, 0.7329942 , 0.73330343,
#        0.73050296, 0.73334885, 0.73170739, 0.73297715, 0.73311049])

# %%
# Save the arrays to an HDF5 file
#with h5py.File('accuracy_combined.h5', 'w') as hf:
#    hf.create_dataset('binary_acc', data=binary_acc)
#    hf.create_dataset('val_binary_acc', data=val_binary_acc)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine all the data into a single array
binary_acc = np.array([combined_history_df_run1['binary_accuracy'],
                       combined_history_df_run2['binary_accuracy'],
                       combined_history_df_run3['binary_accuracy'],
                       combined_history_df_run4['binary_accuracy'],
                       combined_history_df_run5['binary_accuracy'],
                       combined_history_df_run6['binary_accuracy'],
                       combined_history_df_run7['binary_accuracy'],
                       combined_history_df_run8['binary_accuracy'],
                       combined_history_df_run9['binary_accuracy'],
                       combined_history_df_run10['binary_accuracy']])

val_binary_acc = np.array([combined_history_df_run1['val_binary_accuracy'],
                           combined_history_df_run2['val_binary_accuracy'],
                           combined_history_df_run3['val_binary_accuracy'],
                           combined_history_df_run4['val_binary_accuracy'],
                           combined_history_df_run5['val_binary_accuracy'],
                           combined_history_df_run6['val_binary_accuracy'],
                           combined_history_df_run7['val_binary_accuracy'],
                           combined_history_df_run8['val_binary_accuracy'],
                           combined_history_df_run9['val_binary_accuracy'],
                           combined_history_df_run10['val_binary_accuracy']])

# Calculate the mean and standard deviation for each array
binary_acc_mean = np.mean(binary_acc, axis=0)
binary_acc_std = np.std(binary_acc, axis=0)

val_binary_acc_mean = np.mean(val_binary_acc, axis=0)
val_binary_acc_std = np.std(val_binary_acc, axis=0)

fig, ax = plt.subplots(figsize=(12, 4))
epochs = np.arange(1, len(binary_acc_mean)+1)

# Set the colors
error_bar_color = 'red'
cap_top_color = 'black'
cap_bottom_color = 'black'

# Plot the mean values with error bars
ax.errorbar(epochs, binary_acc_mean, yerr=binary_acc_std, label='Training Binary Accuracy', #ecolor='black',
             capsize=5, capthick=1, elinewidth=1, color = 'black', linestyle='--')
ax.errorbar(epochs, val_binary_acc_mean, yerr=val_binary_acc_std, label='Validation Binary Accuracy', #ecolor='red',
              capsize=5, capthick=1, elinewidth=1, color = 'red', linestyle='--', markeredgecolor='red')

# Set the color of the top and bottom caps
#for errorbar in ax.lines:
#    errorbar.set_markeredgecolor(cap_top_color)

# Add labels and legend
ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.set_title('Training and Validation Accuracy')
ax.legend()

# Show the plot
plt.show()

# %%
binary_acc_std[-1]
# Out:
# 0.0008971440605835807

# %% [markdown]
# # Significance

# %%
with h5py.File('combined_sig_data_run1.h5', 'r') as hf:
    sig_df_run1 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run2.h5', 'r') as hf:
    sig_df_run2 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run3.h5', 'r') as hf:
    sig_df_run3 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run4.h5', 'r') as hf:
    sig_df_run4 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run5.h5', 'r') as hf:
    sig_df_run5 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run6.h5', 'r') as hf:
    sig_df_run6 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run7.h5', 'r') as hf:
    sig_df_run7 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run8.h5', 'r') as hf:
    sig_df_run8 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run9.h5', 'r') as hf:
    sig_df_run9 = pd.DataFrame(hf['df'][:])
with h5py.File('combined_sig_data_run10.h5', 'r') as hf:
    sig_df_run10 = pd.DataFrame(hf['df'][:])

# %%
columns = ['syst_uncertainty (%)', 'Significances', 'Threshold', 'no_bg', 'no_signal']

sig_df_run1 =sig_df_run1.rename(columns=dict(zip(sig_df_run1, columns)))
sig_df_run2 =sig_df_run2.rename(columns=dict(zip(sig_df_run2, columns)))
sig_df_run3 =sig_df_run3.rename(columns=dict(zip(sig_df_run3, columns)))
sig_df_run4 =sig_df_run4.rename(columns=dict(zip(sig_df_run4, columns)))
sig_df_run5 =sig_df_run5.rename(columns=dict(zip(sig_df_run5, columns)))
sig_df_run6 =sig_df_run6.rename(columns=dict(zip(sig_df_run6, columns)))
sig_df_run7 =sig_df_run7.rename(columns=dict(zip(sig_df_run7, columns)))
sig_df_run8 =sig_df_run8.rename(columns=dict(zip(sig_df_run8, columns)))
sig_df_run9 =sig_df_run9.rename(columns=dict(zip(sig_df_run9, columns)))
sig_df_run10 =sig_df_run10.rename(columns=dict(zip(sig_df_run10, columns)))

no_syst_1 = sig_df_run1['Significances'][0]
syst_5_1 =  sig_df_run1['Significances'][1]
syst_10_1 = sig_df_run1['Significances'][2]

no_syst_2 = sig_df_run2['Significances'][0]
syst_5_2 =  sig_df_run2['Significances'][1]
syst_10_2 = sig_df_run2['Significances'][2]

no_syst_3 = sig_df_run3['Significances'][0]
syst_5_3 =  sig_df_run3['Significances'][1]
syst_10_3 = sig_df_run3['Significances'][2]

no_syst_4 = sig_df_run4['Significances'][0]
syst_5_4 =  sig_df_run4['Significances'][1]
syst_10_4 = sig_df_run4['Significances'][2]

no_syst_5 = sig_df_run5['Significances'][0]
syst_5_5 =  sig_df_run5['Significances'][1]
syst_10_5 = sig_df_run5['Significances'][2]

no_syst_6 = sig_df_run6['Significances'][0]
syst_5_6 =  sig_df_run6['Significances'][1]
syst_10_6 = sig_df_run6['Significances'][2]

no_syst_7 = sig_df_run7['Significances'][0]
syst_5_7 =  sig_df_run7['Significances'][1]
syst_10_7 = sig_df_run7['Significances'][2]

no_syst_8 = sig_df_run8['Significances'][0]
syst_5_8 =  sig_df_run8['Significances'][1]
syst_10_8 = sig_df_run8['Significances'][2]

no_syst_9 = sig_df_run9['Significances'][0]
syst_5_9 =  sig_df_run9['Significances'][1]
syst_10_9 = sig_df_run9['Significances'][2]

no_syst_10 = sig_df_run10['Significances'][0]
syst_5_10 =  sig_df_run10['Significances'][1]
syst_10_10 = sig_df_run10['Significances'][2]

no_syst = [no_syst_1,no_syst_2,no_syst_3,no_syst_4,no_syst_5,no_syst_6,no_syst_7,no_syst_8,no_syst_9,no_syst_10]
syst_5 = [syst_5_1,syst_5_2,syst_5_3,syst_5_4,syst_5_5,syst_5_6,syst_5_7,syst_5_8,syst_5_9,syst_5_10]
syst_10 = [syst_10_1,syst_10_2,syst_10_3,syst_10_4,syst_10_5,syst_10_6,syst_10_7,syst_10_8,syst_10_9,syst_10_10]

# %%
# create a figure and axis object
fig, ax = plt.subplots()

# create a boxplot of the data in roc_auc
ax.boxplot(no_syst)

# set axis labels and title
ax.set_ylabel('Significance')
ax.set_xlabel('FNN')
ax.set_title('Boxplot of Significance with no systematic uncertainty')
# Out:
# Text(0.5, 1.0, 'Boxplot of Significance with no systematic uncertainty')

# %%
# create a figure and axis object
fig, ax = plt.subplots()

# create a boxplot of the data in roc_auc
ax.boxplot(syst_5, sym='', whis=1.5)#showfliers=False)#flierprops={'marker': 'o', 'markersize': 8, 'linestyle': '-'})

# set axis labels and title
ax.set_ylabel('Significance')
ax.set_xlabel('FNN')
ax.set_title('Boxplot of Significance with 5% uncertainty')
# Out:
# Text(0.5, 1.0, 'Boxplot of Significance with 5% uncertainty')

# %%
#syst_5[3] = 10.9 
#syst_5[8] = 11.1 

#syst_5[6]=10.1

syst_5
# Out:
# [10.291310056913964,
#  10.440829219880827,
#  10.230937829833957,
#  11.076632625880416,
#  10.932426494068983,
#  10.152228187233256,
#  9.707781651429428,
#  10.18772323280315,
#  10.287789599274507,
#  10.82585065074371]

# %%
# create a figure and axis object
fig, ax = plt.subplots()

# create a boxplot of the data in roc_auc
ax.boxplot(syst_10)

# set axis labels and title
ax.set_ylabel('Significance')
ax.set_xlabel('FNN')
ax.set_title('Boxplot of Significance with 10% uncertainty')
# Out:
# Text(0.5, 1.0, 'Boxplot of Significance with 10% uncertainty')

# %%
no_syst_mean = np.mean(no_syst)
no_syst_std = np.std(no_syst)

syst_5_mean = np.mean(syst_5)
syst_5_std = np.std(syst_5)

syst_10_mean = np.mean(syst_10)
syst_10_std = np.std(syst_10)

print(f'No systematic uncertainty, significance: {no_syst_mean} +- {no_syst_std}')
print()
print(f'5% systematic uncertainty, significance: {syst_5_mean} +- {syst_5_std}')
print()
print(f'10% systematic uncertainty, significance: {syst_10_mean} +- {syst_10_std}')
# Out:
# No systematic uncertainty, significance: 14.833712172300348 +- 0.14322350100642223
#
# 5% systematic uncertainty, significance: 10.41335095480622 +- 0.3951136846929329
#
# 10% systematic uncertainty, significance: 8.37672034673039 +- 0.7329765303886768

# %%
# Number of Events over all runs average
no_bg_events = np.array([sig_df_run1['no_bg'],
                       sig_df_run2['no_bg'],
                       sig_df_run3['no_bg'],
                       sig_df_run4['no_bg'],
                       sig_df_run5['no_bg'],
                       sig_df_run6['no_bg'],
                       sig_df_run7['no_bg'],
                       sig_df_run8['no_bg'],
                       sig_df_run9['no_bg'],
                       sig_df_run10['no_bg']])

no_signal_events = np.array([sig_df_run1['no_signal'],
                           sig_df_run2['no_signal'],
                           sig_df_run3['no_signal'],
                           sig_df_run4['no_signal'],
                           sig_df_run5['no_signal'],
                           sig_df_run6['no_signal'],
                           sig_df_run7['no_signal'],
                           sig_df_run8['no_signal'],
                           sig_df_run9['no_signal'],
                           sig_df_run10['no_signal']])


# Calculate the mean and standard deviation for each array, at peak significance
no_bg_events_mean = np.mean(no_bg_events, axis=0)
no_bg_events_std = np.std(no_bg_events, axis=0)

no_signal_events_mean = np.mean(no_signal_events, axis=0)
no_signal_events_std = np.std(no_signal_events, axis=0)

print(f'Mean number of bg events = {no_bg_events_mean}')
print(f'Std on number of bg events = {no_bg_events_std}')
print()
print(f'Mean number of signal events = {no_signal_events_mean}')
print(f'Std on number of signal events = {no_signal_events_std}')
# Out:
# Mean number of bg events = [2481.1640625  130.1796875   43.615625 ]
# Std on number of bg events = [1091.97911861   68.70911968   24.78945246]
#
# Mean number of signal events = [758.34282227 161.00830078  85.57558594]
# Std on number of signal events = [152.09579032  53.08322884  22.39965096]

# %%
# Combine all the data into a single array
optimal_thresholds = np.array([sig_df_run1['Threshold'],
                       sig_df_run2['Threshold'],
                       sig_df_run3['Threshold'],
                       sig_df_run4['Threshold'],
                       sig_df_run5['Threshold'],
                       sig_df_run6['Threshold'],
                       sig_df_run7['Threshold'],
                       sig_df_run8['Threshold'],
                       sig_df_run9['Threshold'],
                       sig_df_run10['Threshold']])

# Calculate the mean and standard deviation for each array, of peak significance
optimal_thresholds_mean = np.mean(optimal_thresholds, axis=0)
optimal_thresholds_std = np.std(optimal_thresholds, axis=0)

optimal_thresholds[:,1] # 0.96 is median, with 5/10. 0.967 is mean


# only include values if the threshold is 0.95, this was the median threshold, true for 7/10 (70%) models
optimal_threshold_mask = optimal_thresholds[:,1] == 0.96

# %%
optimal_thresholds
# Out:
# array([[0.85, 0.96, 0.98],
#        [0.91, 0.96, 0.98],
#        [0.83, 0.96, 0.98],
#        [0.91, 0.98, 0.98],
#        [0.89, 0.97, 0.98],
#        [0.87, 0.98, 0.98],
#        [0.89, 0.96, 0.97],
#        [0.86, 0.96, 0.98],
#        [0.9 , 0.97, 0.98],
#        [0.88, 0.97, 0.97]])

# %%
# Number of events over runs where only the median average significance is used
no_bg_events = np.array([sig_df_run1['no_bg'],
                       sig_df_run2['no_bg'],
                       sig_df_run3['no_bg'],
                       sig_df_run4['no_bg'],
                       sig_df_run5['no_bg'],
                       sig_df_run6['no_bg'],
                       sig_df_run7['no_bg'],
                       sig_df_run8['no_bg'],
                       sig_df_run9['no_bg'],
                       sig_df_run10['no_bg']])

no_signal_events = np.array([sig_df_run1['no_signal'],
                           sig_df_run2['no_signal'],
                           sig_df_run3['no_signal'],
                           sig_df_run4['no_signal'],
                           sig_df_run5['no_signal'],
                           sig_df_run6['no_signal'],
                           sig_df_run7['no_signal'],
                           sig_df_run8['no_signal'],
                           sig_df_run9['no_signal'],
                           sig_df_run10['no_signal']])


# Calculate the mean and standard deviation for each array, at peak significance
no_bg_events_mean = np.mean(no_bg_events[optimal_threshold_mask], axis=0)
no_bg_events_std = np.std(no_bg_events[optimal_threshold_mask], axis=0)

no_signal_events_mean = np.mean(no_signal_events[optimal_threshold_mask], axis=0)
no_signal_events_std = np.std(no_signal_events[optimal_threshold_mask], axis=0)

print(f'Mean number of bg events = {no_bg_events_mean}')
print(f'Std on number of bg events = {no_bg_events_std}')
print()
print(f'Mean number of signal events = {no_signal_events_mean}')
print(f'Std on number of signal events = {no_signal_events_std}')
# Out:
# Mean number of bg events = [2966.15625   192.15625    48.840625]
# Std on number of bg events = [1297.72474793   14.3371138    26.88536573]
#
# Mean number of signal events = [821.33813477 205.96025391  84.32402344]
# Std on number of signal events = [177.60566596  13.83344817  20.97855225]

# %% [markdown]
# # Save all data to combine boxplots

# %%
data = {'ROC_Vals': roc_auc, 'Accuracy_Vals': acc_array, 'Significance_Vals_0': no_syst,
       'Significance_Vals_5': syst_5, 'Significance_Vals_10': syst_10}
df = pd.DataFrame(data)


# Save the DataFrame to an HDF5 file
with h5py.File('combined_data.h5', 'w') as hf:
    hf.create_dataset('df', data=df)
    
# with h5py.File('run1_ROC_data.h5', 'r') as hf:
#     df = pd.DataFrame(hf['df'][:])

# %%
data = {'ROC_Vals': roc_auc, 'Accuracy_Vals': acc_array, 'Significance_Vals_0': no_syst,
       'Significance_Vals_5': syst_5, 'Significance_Vals_10': syst_10}
df = pd.DataFrame(data)

df

#Index(['ROC_Vals', 'Accuracy_Vals', 'Significance_Vals_0',
      # 'Significance_Vals_5', 'Significance_Vals_10'],
      #dtype='object')
# Out:
#    ROC_Vals  Accuracy_Vals  Significance_Vals_0  Significance_Vals_5  \
# 0  0.794249       0.733180            14.751270            10.291310
# 1  0.794936       0.732082            14.956239            10.440829
# 2  0.794345       0.731409            14.761832            10.230938
# 3  0.794072       0.732994            14.814771            11.076633
# 4  0.793076       0.733303            14.818217            10.932426
# 5  0.792900       0.730503            14.757807            10.152228
# 6  0.793537       0.733349            14.556144             9.707782
# 7  0.792523       0.731707            14.962815            10.187723
# 8  0.793148       0.732977            14.845117            10.287790
# 9  0.792441       0.733110            15.112910            10.825851
#
#    Significance_Vals_10
# 0              8.106284
# 1              8.139255
# 2              8.135665
# 3              9.744910
# 4              8.841089
# 5              9.103377
# 6              6.919972
# 7              7.749755
# 8              8.604861
# 9              8.422035
